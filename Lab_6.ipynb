# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabbarsyed/PAI_LAB/blob/main/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
Heart_Disease = pd.read_csv('/content/heart_2020_cleaned.csv')
#titanic.to_csv('titanic.csv')

# %%
Heart_Disease
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
Heart_Disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
Heart_Disease.shape
# Out:
# (319795, 18)

# %%
Heart_Disease.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
Heart_Disease.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
Heart_Disease.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
Heart_Disease.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
Heart_Disease['Diabetic'].unique()
# Out:
# array(['Yes', 'No', 'No, borderline diabetes', 'Yes (during pregnancy)'],
#       dtype=object)

# %%
mapping = {
    'Male': 0,
    'Female': 1
}
Heart_Disease['Sex'] = Heart_Disease['Sex'].map(mapping)
Heart_Disease.head()

mapping = {
    'No': 0,
    'Yes': 1
}
Heart_Disease['HeartDisease'] = Heart_Disease['HeartDisease'].map(mapping)
Heart_Disease['Smoking'] = Heart_Disease['Smoking'].map(mapping)
Heart_Disease['AlcoholDrinking'] = Heart_Disease['AlcoholDrinking'].map(mapping)
Heart_Disease['Stroke'] = Heart_Disease['Stroke'].map(mapping)
Heart_Disease['DiffWalking'] = Heart_Disease['DiffWalking'].map(mapping)
Heart_Disease['PhysicalActivity'] = Heart_Disease['PhysicalActivity'].map(mapping)
Heart_Disease['Asthma'] = Heart_Disease['Asthma'].map(mapping)
Heart_Disease['KidneyDisease'] = Heart_Disease['KidneyDisease'].map(mapping)
Heart_Disease['SkinCancer'] = Heart_Disease['SkinCancer'].map(mapping)
Heart_Disease.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0    1        55-59  White      Yes
# 1           0.0            0    1  80 or older  White       No
# 2          30.0            0    0        65-69  White      Yes
# 3           0.0            0    1        75-79  White       No
# 4           0.0            1    1        40-44  White       No
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
Heart_Disease['GenHealth'].unique()
# Out:
# array(['Very good', 'Fair', 'Good', 'Poor', 'Excellent'], dtype=object)

# %%
mapping = {
    'Poor': 0,
    'Fair': 1,
    'Good': 2,
    'Very good': 3,
    'Excellent': 4
}

Heart_Disease['GenHealth'] = Heart_Disease['GenHealth'].map(mapping)
Heart_Disease.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0    1        55-59  White      Yes
# 1           0.0            0    1  80 or older  White       No
# 2          30.0            0    0        65-69  White      Yes
# 3           0.0            0    1        75-79  White       No
# 4           0.0            1    1        40-44  White       No
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
Heart_Disease['AgeCategory'].unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'],
#       dtype=object)

# %%
mapping = {
    '18-24': 0,
    '25-29': 1,
    '30-34': 2,
    '35-39': 3,
    '40-44': 4,
    '45-49': 5,
    '50-54': 6,
    '55-59': 7,
    '60-64': 8,
    '65-69': 9,
    '70-74': 10,
    '75-79': 11,
    '80 or older': 12
}

Heart_Disease['AgeCategory'] = Heart_Disease['AgeCategory'].map(mapping)
Heart_Disease.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0    1            7  White      Yes
# 1           0.0            0    1           12  White       No
# 2          30.0            0    0            9  White      Yes
# 3           0.0            0    1           11  White       No
# 4           0.0            1    1            4  White       No
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
Heart_Disease['Race'].unique()
# Out:
# array(['White', 'Black', 'Asian', 'American Indian/Alaskan Native',
#        'Other', 'Hispanic'], dtype=object)

# %%
mapping = {
    'White': 0,
    'Black': 1,
    'Hispanic': 2,
    'Asian': 3,
    'American Indian/Alaskan Native': 4,
    'Other': 5
}

Heart_Disease['Race'] = Heart_Disease['Race'].map(mapping)
Heart_Disease.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race Diabetic  \
# 0          30.0            0    1            7     0      Yes
# 1           0.0            0    1           12     0       No
# 2          30.0            0    0            9     0      Yes
# 3           0.0            0    1           11     0       No
# 4           0.0            1    1            4     0       No
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
print('Null:\n', Heart_Disease.isnull().sum())
# Out:
# Null:
#  HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
Heart_Disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   AgeCategory       319795 non-null  int64
#  10  Race              319795 non-null  int64
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  int64
#  13  GenHealth         319795 non-null  int64
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  int64
# ...

# %%
sns.countplot(x='HeartDisease',data=Heart_Disease,palette='rainbow')
# Out:
# <ipython-input-28-f5bd8c5dd1c7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HeartDisease',data=Heart_Disease,palette='rainbow')
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
sns.countplot(x='HeartDisease',hue='Sex',data=Heart_Disease,palette='rainbow')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
sns.countplot(x='HeartDisease',hue='BMI',data=Heart_Disease,palette='rainbow')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
sns.countplot(x='HeartDisease',data=Heart_Disease,palette='rainbow')
# Out:
# <ipython-input-32-f5bd8c5dd1c7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HeartDisease',data=Heart_Disease,palette='rainbow')
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
sns.histplot(Heart_Disease['AgeCategory'])
# Out:
# <Axes: xlabel='AgeCategory', ylabel='Count'>

# %%
sns.boxplot(y='AgeCategory', x='Race', data=Heart_Disease)
# Out:
# <Axes: xlabel='Race', ylabel='AgeCategory'>

# %%
sns.boxplot(y='AgeCategory', data=Heart_Disease)
# Out:
# <Axes: ylabel='AgeCategory'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Load and preprocess the data
df = Heart_Disease

# Assuming 'Yes' and 'No' are in a column like 'target_column_name',
# and other categorical columns might exist in the data.
for column in df.columns:
    if df[column].dtype == 'object':
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])

# Separate features and target
X = df.drop(columns=['HeartDisease']).values  # replace 'target_column_name' with the actual column name
y = df['HeartDisease'].values

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
num_features = X_train.shape[1]
print("Number of features:", num_features)
# Out:
# Number of features: 17

# %%
import numpy as np
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline

# Pad to the nearest perfect square (if needed)
desired_size = int(np.ceil(np.sqrt(num_features)) ** 2)
padding_size = desired_size - num_features
X_train_padded = np.pad(X_train, ((0, 0), (0, padding_size)), 'constant')
X_test_padded = np.pad(X_test, ((0, 0), (0, padding_size)), 'constant')

# Now reshape the padded data
side_length = int(np.sqrt(desired_size))
X_train_cnn = X_train_padded.reshape(-1, 1, side_length, side_length).astype(np.float32)
X_test_cnn = X_test_padded.reshape(-1, 1, side_length, side_length).astype(np.float32)

# %%
# # Assuming 16 features, reshape into (1, 4, 4) for CNN input
# X_train_cnn = X_train.reshape(-1, 1, 4, 4).astype(np.float32)
# X_test_cnn = X_test.reshape(-1, 1, 4, 4).astype(np.float32)

# Convert labels to the right format
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

# %%
Heart_Disease.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    1            7     0         2
# 1           0.0            0    1           12     0         0
# 2          30.0            0    0            9     0         2
# 3           0.0            0    1           11     0         0
# 4           0.0            1    1            4     0         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
sns.countplot(x='HadHeartAttack',data=Heart_Disease,palette='rainbow')
# Out:
# <ipython-input-15-362de06a8a99>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HadHeartAttack',data=Heart_Disease,palette='rainbow')
# <Axes: xlabel='HadHeartAttack', ylabel='count'>

# %%
sns.countplot(x='HadHeartAttack',hue='Sex',data=Heart_Disease,palette='rainbow')
# Out:
# <Axes: xlabel='HadHeartAttack', ylabel='count'>

# %%
sns.countplot(x='HadHeartAttack',hue='Pclass',data=train,palette='rainbow')
